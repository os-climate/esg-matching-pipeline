# %% [markdown]
# # RMI Pre-processing

# %%
import pandas as pd
import os
pd.set_option('display.max_columns',50)
from dotenv import dotenv_values, load_dotenv

# S3_ACCESS_KEY=AKIAZNQ2HXS5AYTYQQFJ
# S3_SECRET_KEY=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

# %% [markdown]
# ## 1. Set up to read RMI from the S3

# %%
env_var = dotenv_values('../../.env')

# %%
import boto3
s3_resource = boto3.resource(
    service_name="s3",
    endpoint_url=env_var['S3_ENDPOINT'],
    aws_access_key_id=env_var['S3_ACCESS_KEY'],
    aws_secret_access_key=env_var['S3_SECRET_KEY'],
)
bucket_name = env_var['S3_BUCKET']
bucket = s3_resource.Bucket(bucket_name)

# %% [markdown]
# ## 2. EDA
#
# * assets_earnings  => detailed breakdown of utility assets in electric rate base, and earnings on these assets.
#
# * operations_emissions => capacity, generation, capacity factor, and emissions of CO2, NOx, and SOx for each portion of each plant owned by each utility.
#
# * emissions_targets => CO2 emissions and projections, as well as electricity generation and projections and comparison to RMI's 1.5C decarbonization pathway for the US electricity sector.
#
# * customer_bills => detailed breakdown of electric revenues and the average residential customer bill for each utility.
#
# * utility_information => utility identifiers such as name, ID numbers from various sources, and utility type.

# %% [markdown]
# #### a. Asset earning
# * 43602 rows | 11 col
# * 274 uniques id

# %%
assets_earnings = bucket.Object('RMI/RMI Utility Transition Hub Data/assets_earnings.csv').get()['Body']
asset_df = pd.read_csv(assets_earnings, encoding='utf-8', delimiter=',', low_memory=False)

# %%
asset_df.shape
# Out:
# (43602, 11)

# %%
asset_df.head()
# Out:
#                       parent_company        utility_name  respondent_id  year  \
# 0  American Electric Power Co., Inc.  AEP Generating Co.              1  2005
# 1  American Electric Power Co., Inc.  AEP Generating Co.              1  2005
# 2  American Electric Power Co., Inc.  AEP Generating Co.              1  2005
# 3  American Electric Power Co., Inc.  AEP Generating Co.              1  2005
# 4  American Electric Power Co., Inc.  AEP Generating Co.              1  2005
#
#    asset                           sub_asset  asset_value  equity_ratio  ROE  \
# 0  other                                AROs   -1370143.0      0.529609  0.0
# 1  other  electric_plant_held_for_future_use    1112267.0      0.529609  0.0
# 2  other     electric_plant_leased_to_others   12227414.0      0.529609  0.0
# 3  other                       general_plant     646114.0      0.529609  0.0
# 4  other                    intangible_plant    1155941.0      0.529609  0.0
#
#         ROR  earnings_value
# 0  0.040655            -0.0
# 1  0.040655             0.0
# 2  0.040655             0.0
# 3  0.040655             0.0
# 4  0.040655             0.0

# %%
asset_df['respondent_id'].nunique()
# Out:
# 274

# %% [markdown]
# #### b. Emissions targets
# * 10061 rows | 15 cols
# * 192 unique id

# %%
emission_tgt = bucket.Object('RMI/RMI Utility Transition Hub Data/emissions_targets.csv').get()['Body']
emission_tgt_df = pd.read_csv(emission_tgt, encoding='utf-8', delimiter=',', low_memory=False)

# %%
emission_tgt_df.shape
# Out:
# (10061, 15)

# %%
emission_tgt_df.head()
# Out:
#                       parent_company        utility_name  respondent_id  \
# 0  American Electric Power Co., Inc.  AEP Generating Co.            1.0
# 1  American Electric Power Co., Inc.  AEP Generating Co.            1.0
# 2  American Electric Power Co., Inc.  AEP Generating Co.            1.0
# 3  American Electric Power Co., Inc.  AEP Generating Co.            1.0
# 4  American Electric Power Co., Inc.  AEP Generating Co.            1.0
#
#      year  CO2_historical  CO2_target  CO2_target_all_years  CO2_1point5C  \
# 0  2000.0        0.324787         NaN                   NaN      4.034557
# 1  2001.0        0.000000         NaN                   NaN      3.969040
# 2  2002.0        0.000000         NaN                   NaN      3.995914
# 3  2003.0        0.000000         NaN                   NaN      4.050336
# 4  2004.0        0.000000         NaN                   NaN      4.104741
#
#    generation_historical  generation_projected  generation_1point5C  \
# 0               7.276847                   NaN             3.555941
# 1               1.000000                   NaN             3.494718
# 2               1.000000                   NaN             3.608640
# 3               1.000000                   NaN             3.631772
# 4               1.000000                   NaN             3.713485
#
#    CO2_intensity_historical  CO2_intensity_target  \
# 0                  0.044633                   NaN
# 1                  0.000000                   NaN
# 2                  0.000000                   NaN
# 3                  0.000000                   NaN
# 4                  0.000000                   NaN
#
#    CO2_intensity_target_all_years  CO2_intensity_1point5C
# 0                             NaN                1.134596
# 1                             NaN                1.135725
# 2                             NaN                1.107318
# 3                             NaN                1.115251
# 4                             NaN                1.105361

# %%
emission_tgt_df['respondent_id'].nunique()
# Out:
# 192

# %% [markdown]
# #### c. Operations emissions
# * 352072rows | 23 col
# * 199 respondent_id unique
# * longitude and latitude filled at 94%

# %%
emission_op = bucket.Object('RMI/RMI Utility Transition Hub Data/operations_emissions.csv').get()['Body']
emission_op_df = pd.read_csv(emission_op, encoding='utf-8', delimiter=',', low_memory=False)

# %%
emission_op_df.shape
# Out:
# (352072, 23)

# %%
emission_op_df.head()
# Out:
#                       parent_company        utility_name  respondent_id  \
# 0  American Electric Power Co., Inc.  AEP Generating Co.              1
# 1  American Electric Power Co., Inc.  AEP Generating Co.              1
# 2  American Electric Power Co., Inc.  AEP Generating Co.              1
# 3  American Electric Power Co., Inc.  AEP Generating Co.              1
# 4  American Electric Power Co., Inc.  AEP Generating Co.              1
#
#    plant_id_eia generator_id owned_or_total Latitude Longitude state  \
# 0        6166.0            1          owned      NaN       NaN    IN
# 1        6166.0            1          owned      NaN       NaN    IN
# 2        6166.0            2          owned      NaN       NaN    IN
# 3        6166.0            2          owned      NaN       NaN    IN
# 4           NaN          NaN          total      NaN       NaN   NaN
#
#   NERC Region Balancing Authority Code Balancing Authority Name    year  \
# 0         NaN                      NaN                      NaN  2019.0
# 1         NaN                      NaN                      NaN  2019.0
# 2         NaN                      NaN                      NaN  2019.0
# 3         NaN                      NaN                      NaN  2019.0
# 4         NaN                      NaN                      NaN  2019.0
#
#   status           technology_EIA technology_RMI fuel_type_code  \
# 0     OP  Conventional Steam Coal          Steam            SUB
# 1     OP  Conventional Steam Coal          Steam            BIT
# 2     OP  Conventional Steam Coal          Steam            SUB
# 3     OP  Conventional Steam Coal          Steam            BIT
# 4     OP        Energy Efficiency      EE and DR            NaN
#
#   fuel_type_category  capacity  generation  potential_generation  \
# 0               coal     0.455    1.173559                3.9858
# 1               coal     0.455    0.226424                3.9858
# 2               coal     0.455    1.216699                3.9858
# 3               coal     0.455    0.234748                3.9858
# 4                NaN       NaN         NaN                   NaN
#
#    capacity_factor  emissions_CO2
# 0         0.294435       1.171257
# 1         0.056808       0.216950
# 2         0.305259       1.214313
# 3         0.058896       0.224925
# 4              NaN            NaN

# %%
emission_op_df[~emission_op_df['Latitude'].isna()]
# Out:
#                            parent_company                      utility_name  \
# 31      American Electric Power Co., Inc.                AEP Generating Co.
# 32      American Electric Power Co., Inc.                AEP Generating Co.
# 33      American Electric Power Co., Inc.                AEP Generating Co.
# 34      American Electric Power Co., Inc.                AEP Generating Co.
# 35      American Electric Power Co., Inc.                AEP Generating Co.
# ...                                   ...                               ...
# 352062         Basin Electric Power Coop.  Basin Electric Power Cooperative
# 352063         Basin Electric Power Coop.  Basin Electric Power Cooperative
# 352064         Basin Electric Power Coop.  Basin Electric Power Cooperative
# 352065         Basin Electric Power Coop.  Basin Electric Power Cooperative
# 352066         Basin Electric Power Coop.  Basin Electric Power Cooperative
#
#         respondent_id  plant_id_eia generator_id owned_or_total   Latitude  \
# 31                  1       55502.0         0100          owned    39.0911
# 32                  1       55502.0         0100          owned    39.0911
# 33                  1       55502.0         0100          owned    39.0911
# 34                  1       55502.0         0100          owned    39.0911
# 35                  1       55502.0         0200          owned    39.0911
# ...               ...           ...          ...            ...        ...
# 352062            531        8030.0            3          owned    43.7219
# 352063            531       55995.0          MWP          owned  48.021271
# 352064            531       55995.0          MWP          owned  48.021271
# 352065            531       55995.0          MWP          owned  48.021271
# 352066            531       55995.0          MWP          owned  48.021271
#
#           Longitude state NERC Region Balancing Authority Code  \
# 31         -84.8669    IN         RFC                      PJM
# 32         -84.8669    IN         RFC                      PJM
# 33         -84.8669    IN         RFC                      PJM
# 34         -84.8669    IN         RFC                      PJM
# 35         -84.8669    IN         RFC                      PJM
# ...             ...   ...         ...                      ...
# 352062    -105.7689    WY        WECC                     WACM
# 352063  -101.280517    ND         MRO                     MISO
# 352064  -101.280517    ND         MRO                     MISO
# 352065  -101.280517    ND         MRO                     SWPP
# 352066  -101.280517    ND         MRO                     SWPP
#
#                                  Balancing Authority Name    year status  \
# 31                               PJM Interconnection, LLC  2016.0     OP
# 32                               PJM Interconnection, LLC  2016.0     OP
# 33                               PJM Interconnection, LLC  2016.0     OP
# 34                               PJM Interconnection, LLC  2016.0     OP
# 35                               PJM Interconnection, LLC  2016.0     OP
# ...                                                   ...     ...    ...
# 352062  Western Area Power Administration - Rocky Moun...  2005.0     OP
# 352063  Midcontinent Independent Transmission System O...  2005.0     OP
# 352064  Midcontinent Independent Transmission System O...  2005.0     OP
# 352065                               Southwest Power Pool  2005.0     OP
# 352066                               Southwest Power Pool  2005.0     OP
#
#                               technology_EIA          technology_RMI  \
# 31          Natural Gas Fired Combined Cycle            Other Fossil
# 32          Natural Gas Fired Combined Cycle            Other Fossil
# 33          Natural Gas Fired Combined Cycle            Other Fossil
# 34          Natural Gas Fired Combined Cycle            Other Fossil
# 35          Natural Gas Fired Combined Cycle            Other Fossil
# ...                                      ...                     ...
# 352062  Natural Gas Fired Combustion Turbine            Other Fossil
# 352063                  Onshore Wind Turbine  Renewables and Storage
# 352064                  Onshore Wind Turbine  Renewables and Storage
# 352065                  Onshore Wind Turbine  Renewables and Storage
# 352066                  Onshore Wind Turbine  Renewables and Storage
#
#        fuel_type_code fuel_type_category  capacity  generation  \
# 31                 NG                gas    0.2680    1.246452
# 32                 NG                gas    0.2680    1.246452
# 33                 NG                gas    0.2680    1.246452
# 34                 NG                gas    0.2680    1.246452
# 35                 NG                gas    0.2680    1.246452
# ...               ...                ...       ...         ...
# 352062             NG                gas    0.0075    0.000051
# 352063            WND               wind    0.0026    0.005251
# 352064            WND               wind    0.0026    0.005251
# 352065            WND               wind    0.0026    0.005251
# 352066            WND               wind    0.0026    0.005251
#
#         potential_generation  capacity_factor  emissions_CO2
# 31                  2.354112         0.529479       0.000000
# 32                  2.354112         0.529479       0.000000
# 33                  2.354112         0.529479       0.000000
# 34                  2.354112         0.529479       0.000000
# 35                  2.354112         0.529479       0.000000
# ...                      ...              ...            ...
# 352062              0.065700         0.000776       0.000039
# 352063              0.022776         0.230550       0.000000
# 352064              0.022776         0.230550       0.000000
# 352065              0.022776         0.230550       0.000000
# 352066              0.022776         0.230550       0.000000
#
# [330311 rows x 23 columns]

# %%
emission_op_df['respondent_id'].nunique()
# Out:
# 199

# %% [markdown]
# #### d. Revenues bills

# %%
revenues = bucket.Object('RMI/RMI Utility Transition Hub Data/revenues_bills.csv').get()['Body']
revenues_df = pd.read_csv(revenues, encoding='utf-8', delimiter=',', low_memory=False)

# %%
revenues_df.shape
# Out:
# (96144, 11)

# %%
revenues_df.head()
# Out:
#                       parent_company        utility_name  respondent_id  \
# 0  American Electric Power Co., Inc.  AEP Generating Co.              1
# 1  American Electric Power Co., Inc.  AEP Generating Co.              1
# 2  American Electric Power Co., Inc.  AEP Generating Co.              1
# 3  American Electric Power Co., Inc.  AEP Generating Co.              1
# 4  American Electric Power Co., Inc.  AEP Generating Co.              1
#
#      year revenue_component revenue_sub_component  revenue_value  \
# 0  2019.0             other  depreciation_expense   1.904500e+04
# 1  2019.0             other  maintenance_expenses   4.208100e+05
# 2  2019.0             other    operation_expenses   2.847277e+06
# 3  2019.0             other               returns   7.234716e+06
# 4  2019.0             steam  depreciation_expense   5.043549e+07
#
#    sales_residential  sales_total  customers_residential  \
# 0                NaN  306947627.0                    NaN
# 1                NaN  306947627.0                    NaN
# 2                NaN  306947627.0                    NaN
# 3                NaN  306947627.0                    NaN
# 4                NaN  306947627.0                    NaN
#
#    residential_bill_value
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
revenues_df['respondent_id'].nunique()
# Out:
# 339

# %%
revenues_df['utility_name'].nunique()
# Out:
# 336

# %% [markdown]
# #### e. Utility information
# * all the ids

# %%
utility = bucket.Object('RMI/RMI-20210520/utility_information.csv').get()['Body']
utility_df = pd.read_csv(utility, encoding='utf-8', delimiter=',', low_memory=False)

# %%
utility_df.shape
# Out:
# (375, 12)

# %%
utility_df.head()
# Out:
#                       parent_company parent_ticker   parent_ISIN  \
# 0  American Electric Power Co., Inc.           AEP  US0255371017
# 1                       Southern Co.            SO  US8425871071
# 2                       Avista Corp.           AVA  US05379B1070
# 3                        Alcoa Corp.            AA  US0138721065
# 4                  FirstEnergy Corp.            FE  US3379321074
#
#              parent_LEI                       utility_name  respondent_id  \
# 0  1B4S6S7G0TW5EE83BO58                 AEP Generating Co.              1
# 1  549300FC3G3YU2FBZD92                  Alabama Power Co.              2
# 2  Q0IK63NITJD6RJ47SW96  Alaska Electric Light & Power Co.              3
# 3  549300T12EZ1F6PWWU29             Alcoa Generating Corp.              4
# 4  549300SVYJS666PQJH88       The Allegheny Generating Co.              5
#
#    utility_id_eia         entity_type_EIA            utility_type_RMI  \
# 0           343.0  Investor-Owned Utility  Independent Power Producer
# 1           195.0  Investor-Owned Utility       Vertically Integrated
# 2           213.0  Investor-Owned Utility       Vertically Integrated
# 3             NaN              Industrial                       Other
# 4          6458.0  Investor-Owned Utility  Independent Power Producer
#
#    parent_id                        parent_name ticker
# 0       10.0  American Electric Power Co., Inc.    AEP
# 1      142.0                       Southern Co.     SO
# 2       16.0                       Avista Corp.    AVA
# 3        4.0                        Alcoa Corp.     AA
# 4       61.0                  FirstEnergy Corp.     FE

# %% [markdown]
# #### f. Data dictionnary

# %%
data_dict = bucket.Object('RMI/RMI Utility Transition Hub Data/RMI Utility Transition Hub Data Dictionary.xlsx').get()['Body']

# %%
s3 = boto3.client('s3')
s3.download_file(env_var['S3_BUCKET'],
                'RMI/RMI Utility Transition Hub Data/RMI Utility Transition Hub Data Dictionary.xlsx',
                '../../../dico.xlsx')

# %% [markdown]
# #### g. Utility information 2023

# %%
utility = bucket.Object('Entity-Matching/datasets/utility_information_2023.csv').get()['Body']
utility_df = pd.read_csv(utility, encoding='utf-8', delimiter=',', low_memory=False)

# %%
utility_df.shape
# Out:
# (14670, 15)

# %%
utility_df[utility_df[['parent_name','parent_lei',"utility_name"]].duplicated()]
# Out:
#                           parent_name            parent_lei ticker  \
# 88                  National Grid plc  8R95QZMKZLJX5Q2XR704    NGG
# 126                NorthWestern Corp.  3BPWMBHR1R9SHUN7J795    NWE
# 127                NorthWestern Corp.  3BPWMBHR1R9SHUN7J795    NWE
# 128                NorthWestern Corp.  3BPWMBHR1R9SHUN7J795    NWE
# 194                      Unitil Corp.                   NaN    UTL
# ...                               ...                   ...    ...
# 14373         NRG Power Marketing LLC                   NaN    NaN
# 14514  SunPower Capital Services, LLC                   NaN    NaN
# 14570   Southeast Alaska Power Agency                   NaN    NaN
# 14589              Heritage Power LLC                   NaN    NaN
# 14612                City of Industry                   NaN    NaN
#
#                isin                    utility_name  utility_id_ferc1  \
# 88     US6362744095    National Grid Generation LLC             281.0
# 126    US6680743050              Northwestern Corp.             315.0
# 127    US6680743050              Northwestern Corp.             315.0
# 128    US6680743050              Northwestern Corp.             315.0
# 194    US9132591077              Unitil Power Corp.              42.0
# ...             ...                             ...               ...
# 14373           NaN         NRG Power Marketing LLC               NaN
# 14514           NaN  SunPower Capital Services, LLC               NaN
# 14570           NaN   Southeast Alaska Power Agency               NaN
# 14589           NaN              Heritage Power LLC               NaN
# 14612           NaN                City of Industry               NaN
#
#        utility_id_ferc1_dbf utility_id_ferc1_xbrl  utility_id_eia  \
# 88                     85.0               C001322         26751.0
# 126                   122.0               C001789         56815.0
# 127                   122.0               C001789         13902.0
# 128                   122.0               C001789         13809.0
# 194                   180.0                   NaN             NaN
# ...                     ...                   ...             ...
# 14373                   NaN                   NaN         56784.0
# 14514                   NaN                   NaN         59738.0
# 14570                   NaN                   NaN         60770.0
# 14589                   NaN                   NaN         61264.0
# 14612                   NaN                   NaN         62107.0
#
#                 utility_lei  fraction_owned_utility           entity_type_eia  \
# 88                      NaN                     1.0            Investor Owned
# 126    3BPWMBHR1R9SHUN7J795                     1.0            Investor Owned
# 127    3BPWMBHR1R9SHUN7J795                     1.0            Investor Owned
# 128    3BPWMBHR1R9SHUN7J795                     1.0            Investor Owned
# 194                     NaN                     1.0                       NaN
# ...                     ...                     ...                       ...
# 14373                   NaN                     1.0  Wholesale Power Marketer
# 14514                   NaN                     1.0          Behind the Meter
# 14570                   NaN                     1.0  Wholesale Power Marketer
# 14589                   NaN                     1.0     Retail Power Marketer
# 14612                   NaN                     1.0                 Municipal
#
#                  utility_type_rmi public_private_unmapped  \
# 88     Independent Power Producer                  public
# 126         Vertically Integrated                  public
# 127         Vertically Integrated                  public
# 128         Vertically Integrated                  public
# 194                    Wires Only                  public
# ...                           ...                     ...
# 14373    Wholesale Power Marketer                unmapped
# 14514            Behind the Meter                unmapped
# 14570    Wholesale Power Marketer                unmapped
# 14589       Retail Power Marketer                unmapped
# 14612                   Municipal                unmapped
#
#        duplicate_utility_id_eia
# 88                        False
# 126                       False
# 127                       False
# 128                       False
# 194                       False
# ...                         ...
# 14373                     False
# 14514                     False
# 14570                     False
# 14589                     False
# 14612                     False
#
# [351 rows x 15 columns]

# %%
utility_df['parent_lei'].isna().mean()
# Out:
# 0.9077709611451943

# %%
utility_df.query('utility_name == "Unitil Power Corp."')
# Out:
#       parent_name parent_lei ticker          isin        utility_name  \
# 35   Unitil Corp.        NaN    UTL  US9132591077  Unitil Power Corp.
# 194  Unitil Corp.        NaN    UTL  US9132591077  Unitil Power Corp.
#
#      utility_id_ferc1  utility_id_ferc1_dbf utility_id_ferc1_xbrl  \
# 35              269.0                  35.0               C001248
# 194              42.0                 180.0                   NaN
#
#      utility_id_eia utility_lei  fraction_owned_utility entity_type_eia  \
# 35              NaN         NaN                     1.0             NaN
# 194             NaN         NaN                     1.0             NaN
#
#     utility_type_rmi public_private_unmapped  duplicate_utility_id_eia
# 35        Wires Only                  public                     False
# 194       Wires Only                  public                     False

# %% [markdown]
# Some duplication with utility_name key same lei but different parent & parent lei
#
# 98% lei na for utility
# 90% lei na for the parent

# %% [markdown]
# ## 3. Preprocessing
#
# * In utility we have duplicate with the utility_name
# * RMI cover the USA so we can create a country column set with 'USA'

# %%
## Add the country
utility_df['country'] = 'USA'

# %%
utility_df.query('parent_name == "American Electric Power Co., Inc."').head()
# Out:
#                           parent_name            parent_lei ticker  \
# 0   American Electric Power Co., Inc.  1B4S6S7G0TW5EE83BO58    AEP
# 5   American Electric Power Co., Inc.  1B4S6S7G0TW5EE83BO58    AEP
# 24  American Electric Power Co., Inc.  1B4S6S7G0TW5EE83BO58    AEP
# 31  American Electric Power Co., Inc.  1B4S6S7G0TW5EE83BO58    AEP
# 74  American Electric Power Co., Inc.  1B4S6S7G0TW5EE83BO58    AEP
#
#             isin                 utility_name  utility_id_ferc1  \
# 0   US0255371017           AEP Generating Co.             342.0
# 5   US0255371017        Appalachian Power Co.             200.0
# 24  US0255371017        AEP Texas Central Co.             198.0
# 31  US0255371017  Columbus Southern Power Co.             406.0
# 74  US0255371017   Indiana Michigan Power Co.             201.0
#
#     utility_id_ferc1_dbf utility_id_ferc1_xbrl  utility_id_eia  \
# 0                    1.0               C003184           343.0
# 5                    6.0               C000530           733.0
# 24                  24.0               C000528          3278.0
# 31                  31.0               R001031          4062.0
# 74                  73.0               C000532          9324.0
#
#              utility_lei  fraction_owned_utility entity_type_eia  \
# 0                    NaN                     1.0  Investor Owned
# 5   3SCHO1ABYYIG382BEI70                     1.0  Investor Owned
# 24  O5I1W4NHLL5HR1XYY456                     1.0  Investor Owned
# 31                   NaN                     1.0  Investor Owned
# 74  JHR9V15J0ZRG02MIRD06                     1.0  Investor Owned
#
#               utility_type_rmi public_private_unmapped  \
# 0   Independent Power Producer                  public
# 5        Vertically Integrated                  public
# 24                  Wires Only                  public
# 31                Restructured                  public
# 74       Vertically Integrated                  public
#
#     duplicate_utility_id_eia country
# 0                      False     USA
# 5                      False     USA
# 24                     False     USA
# 31                     False     USA
# 74                     False     USA

# %%
dup_key = ['parent_name','parent_lei',"utility_name",'utility_lei']
utility_df.drop_duplicates(dup_key, inplace=True)

# %%
utility_df.shape
# Out:
# (14321, 16)

# %%
utility_df.reset_index(inplace=True)
utility_df.rename(columns = {'index':'company_id'}, inplace = True)

# %%
utility_df.to_csv('../../../dataset/pre_processed/utilities_pre_processed.csv',index=False)

# %%
### Create Folder
#s3 = boto3.client('s3')
#bucket_name = env_var['S3_BUCKET']
#folder_name = "RMI/raw"
#
#s3.put_object(Bucket=bucket_name, Key=(folder_name+'/'))

# %%
# Save localy
saved_path = "../../../dataset/pre_processed/"
filename = "utilities_pre_processed.csv"

utility_filename = os.path.join(saved_path, filename)
utility_df.to_csv(utility_filename,encoding='utf-8',header=True, index=False)

# %%
for obj in bucket.objects.filter(Prefix="Entity-Matching"):
    print(obj.key)
# Out:
# Entity-Matching/
# Entity-Matching/NAICS.zip
# Entity-Matching/data_download_all.zip
# Entity-Matching/datasets/
# Entity-Matching/datasets/utility_information_2023.csv
# Entity-Matching/elasticsearch/
# Entity-Matching/esg_matching.db
# Entity-Matching/libs/
# Entity-Matching/libs/financial-entity-cleaner-1.0.0.tar.gz
# Entity-Matching/models/
# Entity-Matching/models/all-MiniLM-L6-v2.zip
# Entity-Matching/models/all-distilroberta-v1.zip
# Entity-Matching/models/all-mpnet-base-v2.zip

# %%
# Upload
s3_filename = 'RMI/pre_processed/utilities_pre_processed.csv'
s3_resource.meta.client.upload_file(Filename=utility_filename,
                                    Bucket=env_var['S3_BUCKET'], 
                                    Key=s3_filename)
